# %% [markdown]
# # Bayesian Classifier
# In this lab, you will implement and assess the performance of the Bayesian Classifier.
#
# ## Lab Instructions:
# 1. Read the explanation above each requirement very well
# 2. Read the requirement very well before jumping into the code.
# 3. Some requirements have essay questions in them, make sure you do NOT miss them.
# 4. PLEASE Read the hints! They are clear and made to help you complete the requirement as fast as you should

# %%
#### always keep all your imports in the first cell ####
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import csv
import math

# %% [markdown]
# ## Requirement
#
# In this requirement, you will build the Bayesian Classifier and test its performance.
#
# You are provided with a data file **data1.csv** containing list of points and their corresponding classes. The format of the data files is shown in the table below.
#
# | |Class|Feature 1|Feature 1|
# |-|-|-|-|
# |Point#1|1|0.271633|-2.93224|
# |Point#2|1|7.020786|-1.98966|
# |Point#3|1|2.901827|-0.91291|
#
#
# You are also provided with a test data file **test_data.csv**. The file contains test points that are unlabelled (i.e. the class to which they belong is unknown).

# %%
# TODO [1] : Read the file 'data1.csv' into the variable data.
# data contains the training data together with labelled classes.
def read_data(file_name):
    ## HINT 1: How is the data ordered in the file?
    ## HINT 2: Do you need to cast the data you read from the file?
    data = []
    with open(file_name, 'r') as f:
        reader = csv.reader(f)
        for row in reader:
            data.append([int(float(row[0])), float(row[1]), float(row[2])])
            
    return data

# %%
def read_test_data():
    
    # TODO [2.A]: Read the file 'test_data.csv' into the variable test_data
    # test_data contains the unlabelled test class.
    ## HINT: Do you need to cast the data you read from the file?
    test_data = []
    with open('test_data.csv', 'r') as f:
        reader = csv.reader(f)
        for row in reader:
            test_data.append([float(row[0]), float(row[1])])

    
    # TODO [2.B]: Read the file 'test_data_true.csv' into the variable test_data_true
    # test_data_true contains the actual classes of the test instances, which you will compare
    # against your predicted classes.
    ## HINT: Do you need to cast the data you read from the file?
    test_data_true = []
    with open('test_data_true.csv', 'r') as f:
        reader = csv.reader(f)
        for row in reader:
            test_data_true.append(row[0])
    return test_data, test_data_true

# %% [markdown]
# ### Machine Learning Terminlology
# Machine learning problems use common termonology (names and notiations) to refer to certain things. It is useful to use this termonology throughout your code to make it readable.
#
# | | |
# |:-|:--- |
# |$M$:|A scalar; represents the number of training points in the training set.|
# |$K$:|A scalar; represents the number of test points in the test set.|
# |$N$:|A scalar; represents the number of features of training set/test set (dimensionality of data).|
# |$X$:|A numpy array of shape $(M \times N)$ containing the training data **without** its labels, where $M$ is the number of training points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset.|
# |$X_{test}$:| A numpy array of shape $(K \times N)$ containing the test data, where $K$ is the number of test points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X_{test}$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset. <br/> The number of columns in $X_{test}$ is equal to the number of columns in $X$ (because they have the same number of features). However, the number of rows in $X_{test}$ is different to the number of rows in $X$.|
# |**$Y$:| A numpy array of shape $(M \times 1)$ containing the labels of the training data. Each row in $Y$ corresponds to the label of the training point in $X$.<br/> For example, $Y[j]$ corresponds to the label of the training point $X[j]$ where $0<=j<M$.|

# %%
# TODO [3]: Fill the values of M, K, N, X, XTest, and Y respectively.
# Do not fill them manually (i.e. do not set N = 3). They should be generic for any input file.  
training_data = read_data('data1.csv')
test_data, test_data_true = read_test_data()
numClasses = 3 
M = len(training_data)
N = len(training_data[0])-1
K = len(test_data)
# print(N)

X = np.array([tuple(row[1:]) for row in training_data])
X_Test = np.array([tuple(row) for row in test_data])
Y = np.array([row[0] for row in training_data])

# print(X)
# print(X_Test)
# print(Y)

# %%
# TODO [4]: Draw a scatter plot for traning data, where each class is coloured by the colour corresponding 
#           to its index in the colors array.
# Class 1 should be coloured in red, Class 2 should be coloured in green, and Class 3 should be coloured in blue.
# Hint: We have done a similar plot in the previous lab. What operation do we need to select training data 
#       belonging to a certain class?
def draw_scatter_plot(training_data, labels, colors):
    plt.figure()

    for class_label, color in enumerate(colors, start=1):
        class_data = [training_data[i] for i, label in enumerate(labels) if label == class_label]
        
        x_coords = [point[0] for point in class_data]
        y_coords = [point[1] for point in class_data]
        
        plt.scatter(x_coords, y_coords, c=color, label=f'Class {class_label}')

    plt.legend()

    plt.show()

colors = ['r', 'g', 'b']
print(X)
print(Y)
draw_scatter_plot(X,Y, colors)
# Out:
# [[ 3.27208926  0.72677351]
#  [-6.93777713 -6.44982832]
#  [ 6.05602895  0.48719482]
#  ...
#  [-3.28686863 -5.7977003 ]
#  [-1.15237768 12.15641751]
#  [-1.25571473  6.49572251]]
# [3 1 3 ... 1 2 2]

# %%
## What do you notice about the plot? (Write everything you can think of)
'''
    Your Answer:
    1-The features are overlapping in the middle which will be impossible for the linear classifier to differentiate between
    2-The model won't be 100% accurate in differeniating the classes
'''
# Out:
# "\n    Your Answer:\n    1-The features are overlapping in the middle which will be impossible for the linear classifier to differentiate between\n    2-The model won't be 100% accurate in differeniating the classes\n"

# %% [markdown]
# ### Bayesian Classifier
# The Bayesian Classifier calculates the probability of the test point belonging to each class, then the class with highest probability is assigned to the test point.
#
# Classification of $x_{test}$ = $argmax_{i} P\big(C_i|x_{test}\big)$ = $argmax_{i} P(x|C_i) * P(C_i)$
#
# * $P(C_i|x_{test})$: Posterior probability
# * $P(x|C_i)$: Class-conditional probability (or distribution)
# * $P(C_i)$: Class apriori probability
#
# **Note that** $P(C_i|x_{test}) \neq P(x_{test}|C_i) * P(C_i)$. Instead,  $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$. However, when we compare multiple classes, the denominator $P(x_{test})$ is independent of the class $i$ and can be regarded as normalizing factor.
#
# **We start by** computing statistical parameters about each class from the data.
#
# For each class, we are interested in **three** parameters that will be used for calculating the Gaussian class-conditional distribution and the posterior probability.
#
# These parameters are:
#
# |||
# |:-|:-|
# |**Class Apriori Probability: ($P_C$)**| A scalar; the probability of class occurence (how frequent this class appears in the training data)|
# |**Class Mean: ($\mu$)**| A vector of shape $(N \times 1)$, it is the expected value (mean) calculated from the training points of each class.|
# |**Class Covariance Matrix: ($\Sigma$)**| A square symmetric matrix of shape $(N \times N)$ representing the covariances between all the feature calculated from the training points of the class. <br/> For example: Matrix element $\sigma^2_{12}$ is the covariance between the 1st and the 2nd features|

# %%
pClasses = [] # A list of size (numClasses, 1) containing the a priori probabilities of each class in the training set.

estimate_means = [] # A numpy array of size (numClasses, N) containing the mean points of each class in the training set. 
                    # HINT: USE NP.MEAN

estimate_covariances = [] # A numpy array of size (numClasses, N, N) containing the covariance matrices of each class in the training set.
                          # HINT: USE NP.COV (Pay attenention for what it takes as an argument)
                             
for classIndex in range(numClasses):
    # TODO [5]: Estimate the parameters of the Gaussian distributions of the given classes.
    # Fill pClasses, estimate_means, and estimate_covariances in this part 
    # Your code should be vectorized WITHOUT USING A SINGLE FOR LOOP.
    pClasses.append(np.sum(Y == (classIndex + 1)) / M)
    estimate_means.append(np.mean(X[Y == (classIndex + 1)], axis=0))
    estimate_covariances.append(np.cov(X[Y == (classIndex + 1)], rowvar=False, bias=False))


estimate_means = np.array(estimate_means)
estimate_covariances = np.array(estimate_covariances)

print(pClasses)
print(estimate_means)
print(estimate_covariances)
# Out:
# [np.float64(0.43478260869565216), np.float64(0.34782608695652173), np.float64(0.21739130434782608)]
# [[-4.97082342 -6.02894753]
#  [-0.53823247  9.74350782]
#  [ 5.98539832 -0.07318374]]
# [[[ 5.4561233   3.7145146 ]
#   [ 3.7145146   5.37200937]]
#
#  [[ 1.93492186 -0.19957797]
#   [-0.19957797  7.3401553 ]]
#
#  [[ 5.54603925  0.34284438]
#   [ 0.34284438  5.47798154]]]

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
assert len(pClasses) == numClasses,\
        'Incorrect class apriori probability list, it should be of length {}'.format(len(pClasses))
assert np.isclose(sum(pClasses), 1.0),\
        'Sum of apriori probabilities should be 1, found {}'.format(np.sum(pClasses))

assert estimate_means.shape == (numClasses, N),\
        'Incorrect estimated means, it should be of shape {}'.format((numClasses, N))
assert estimate_covariances.shape == (numClasses, N, N),\
        'Incorrect estimate covariance matrices, it should be of shape {}'.format((numClasses, N, N))

# %% [markdown]
# **The second step** in the classifier is to calculate the class-conditional density using the Gaussian destribution:
#
# $P(x|C_i) = \mathcal{N}(x; \mu_i, \Sigma_i) = \frac{1}{(2\pi)^{\frac{N}{2}}|\Sigma_i|^{\frac{1}{2}}} exp\big(\frac{-1}{2}(x-\mu_i)^T\Sigma^{-1}_{i}(x-\mu_i)\big)$

# %%
# TODO 6: Implement the multivariate normal gaussian distribution with parameters mu and sigma, and return the
#  value in prob.
def multivariate_normal_gaussian(X, mu, sigma):
    prob = None
    sigmadet=np.linalg.det(sigma)
    sigmainv = np.linalg.inv(sigma)
    const=1.0 / (np.power((2 * np.pi), len(X) / 2) * np.sqrt(sigmadet))
    prob= const * np.exp(-0.5 * ((X-mu).T @ sigmainv @(X-mu)))
    return prob

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
np.random.seed(90)
assertion_x = np.random.rand(3).reshape(-1,1)
assertion_mu = np.random.rand(3).reshape(-1,1)
assertion_sigma = np.random.rand(9).reshape(3,3)
assertion_probability = multivariate_normal_gaussian(assertion_x, assertion_mu, assertion_sigma)[0][0]
assertion_probability = round(assertion_probability, 1)

assert assertion_probability == 7.8,\
    'Incorrect Gaussian Probability calculated'

# %% [markdown]
# **The final step** is to go for each test point, calculate its posterior probability against each class, then classify it to the class with the highest posterior probability.

# %%
# TODO [7]: Apply the Bayesian Classifier to predict the classes of the test points.
predicted_classes = [] # predicted_classes: A numpy array of size (K, 1) where K is the number of points in the test set. Every element in this array
                       # contains the predicted class of Bayes classifier for this test point.

for i in range(X_Test.shape[0]):
    print("For test point:", X_Test[i])
    classProbabilities = np.zeros(numClasses)
    # TODO [7.A]: Compute the probability that the test point X_Test[i] belongs to each class in numClasses.
    #  Fill the array classProbabilities accordingly.
    for class_label in range(numClasses):
        classProbabilities[class_label] = multivariate_normal_gaussian(X_Test[i], estimate_means[class_label], estimate_covariances[class_label])*pClasses[class_label]
    
    # TODO [7.B]: Find the prediction of the test point X_Test[i] and append it to the predicted_classes array.
    #  The predicted class is the one with the maximum probability.
    predicted_classes.append(np.argmax(classProbabilities)+1)
    

    print('Class Probabilities: ', classProbabilities)  # the first class is the left most in the scatter plot
    print("Predicted class is :", predicted_classes[i])
    print("******************************************************************************")
# Out:
# For test point: [10.70141426  3.87253627]
# Class Probabilities:  [2.65667378e-12 2.14599814e-17 2.49128533e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.81831787 -5.00977814]
# Class Probabilities:  [1.54057607e-02 1.59733837e-10 1.94606997e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.57071936  9.96036181]
# Class Probabilities:  [7.93462259e-20 1.36556777e-03 5.38717673e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 4.94309043 -0.01539406]
# Class Probabilities:  [1.95768749e-06 1.94246409e-08 5.69470433e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.26082551 -0.61349358]
# Class Probabilities:  [6.24062368e-06 4.98423484e-08 4.72790312e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.98901139 16.86268221]
# Class Probabilities:  [4.48752947e-36 3.09285820e-04 1.66266012e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.2796485  -3.38655342]
# Class Probabilities:  [2.21653333e-03 1.16512385e-07 8.33834079e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.60503344 -0.24206319]
# Class Probabilities:  [8.51743084e-05 1.94834877e-06 2.24458325e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.84312621 12.42130394]
# Class Probabilities:  [7.22909594e-20 5.21791886e-03 1.70142228e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.52253054 10.13668928]
# Class Probabilities:  [3.13513935e-25 1.40321646e-06 7.46137172e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.59472055 -4.37938379]
# Class Probabilities:  [2.85106535e-09 3.52756721e-12 1.15602249e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.98596817 -0.73837508]
# Class Probabilities:  [7.99411940e-04 1.19354041e-06 4.43428961e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.23908496 13.21358765]
# Class Probabilities:  [7.41762417e-26 3.31840114e-03 3.77648976e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -6.7789975 -11.0163502]
# Class Probabilities:  [1.08876577e-03 1.60723615e-20 2.07172921e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.59545273 -0.41955489]
# Class Probabilities:  [5.73709449e-04 1.06972379e-05 4.58273665e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.36129364 -5.42102971]
# Class Probabilities:  [4.93589625e-15 1.81083197e-17 2.37754219e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.52848225 -7.42893531]
# Class Probabilities:  [1.95401646e-03 5.80993828e-12 1.27194655e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.56086046 -9.03278997]
# Class Probabilities:  [2.59963492e-03 2.66267156e-15 4.98120020e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.02188067 -0.93735269]
# Class Probabilities:  [6.30158116e-09 6.99963171e-12 5.27535854e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.1509862  1.43750612]
# Class Probabilities:  [9.02780259e-11 1.11683137e-14 2.17487220e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.71007022 10.6797775 ]
# Class Probabilities:  [6.14531752e-19 9.85768312e-03 2.90112524e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.76302456 -5.55297678]
# Class Probabilities:  [1.71586850e-02 6.63592440e-12 2.25174627e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.89883417 -5.39496672]
# Class Probabilities:  [1.65351144e-02 6.68116262e-12 1.99600315e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.03379007 2.71590677]
# Class Probabilities:  [3.25890828e-09 6.33380428e-12 2.25024371e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.89215726 -2.59460822]
# Class Probabilities:  [2.35266738e-03 1.54638572e-09 1.07116647e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.11834647  4.91066223]
# Class Probabilities:  [1.04649644e-10 8.44017451e-05 3.54716778e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.45717699 -2.43934454]
# Class Probabilities:  [5.07994027e-09 6.00780281e-12 3.64390048e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.56547098 4.9207542 ]
# Class Probabilities:  [2.07859390e-07 1.10058952e-03 8.50552242e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.26265631 6.5794146 ]
# Class Probabilities:  [2.26255545e-09 3.47120364e-03 1.01432187e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.70832433 -3.11174424]
# Class Probabilities:  [3.09054013e-05 2.15868871e-08 1.14306196e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -9.10836917 -11.76552446]
# Class Probabilities:  [8.17206004e-04 1.11871770e-25 1.87039920e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.81726658 -5.3687788 ]
# Class Probabilities:  [1.66047056e-02 8.62791976e-12 2.38357009e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.30975347  9.75343174]
# Class Probabilities:  [1.72678281e-15 1.45116252e-02 1.24168863e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-7.58893623 -3.93631034]
# Class Probabilities:  [6.68507055e-04 2.69710033e-14 1.66023121e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-11.3843618 -12.1472865]
# Class Probabilities:  [2.36182000e-04 1.81519641e-31 1.48001343e-19]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.15303864 -5.99521012]
# Class Probabilities:  [9.52218517e-12 2.65861625e-14 2.49472689e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [0.88072334 9.72115039]
# Class Probabilities:  [2.03278381e-14 8.73359714e-03 5.14055342e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.3263618 8.7977202]
# Class Probabilities:  [1.52281942e-12 5.76223120e-03 4.07909769e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.70501109 11.56174259]
# Class Probabilities:  [1.23831454e-25 1.45196243e-04 2.03066485e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.12643357 -4.83616859]
# Class Probabilities:  [1.28546337e-02 7.52713331e-10 7.01438067e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.05674244 12.57155861]
# Class Probabilities:  [1.42657849e-17 2.98293259e-05 1.47833737e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -4.30106198 -10.6042502 ]
# Class Probabilities:  [1.96590956e-04 6.64738611e-17 5.74518294e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 5.11776496 -0.99143917]
# Class Probabilities:  [8.67064375e-07 3.31293291e-09 5.48755998e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 6.05493358 -5.87189841]
# Class Probabilities:  [1.91155296e-11 4.69464766e-14 2.87311212e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.74275953 -3.97527522]
# Class Probabilities:  [1.18595011e-06 7.60486076e-10 1.09158161e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.02170247 -5.57244813]
# Class Probabilities:  [1.60749255e-02 3.28317694e-11 8.50671996e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.27810154 -3.99998321]
# Class Probabilities:  [7.21775006e-03 4.33520027e-11 2.60633343e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.80988364 3.43699512]
# Class Probabilities:  [1.87857691e-07 4.98276954e-08 2.01393153e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.6311676  1.76165524]
# Class Probabilities:  [5.20542173e-10 1.83337231e-13 2.59042829e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.73761305 -6.16978647]
# Class Probabilities:  [1.72079010e-02 1.82566894e-12 1.32335101e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.28411495 -2.28452888]
# Class Probabilities:  [1.67178440e-21 2.46223913e-27 2.69611652e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.47775397 -0.10213091]
# Class Probabilities:  [4.27672843e-04 5.64424874e-06 9.64961054e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.42758688 -7.1513932 ]
# Class Probabilities:  [1.15591078e-02 3.93607956e-13 8.04615899e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.71805696 -8.49355483]
# Class Probabilities:  [1.41749273e-04 1.02901556e-12 9.19853585e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.07056432 13.27106731]
# Class Probabilities:  [3.48135625e-29 2.95452881e-04 1.19575627e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.82594718 -9.52426172]
# Class Probabilities:  [1.53492747e-04 1.97327367e-14 4.00060710e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.2893587   1.35319816]
# Class Probabilities:  [1.93246613e-12 2.76184820e-17 1.04650738e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.13419282  9.00152907]
# Class Probabilities:  [7.59348245e-15 1.28409785e-02 1.62680532e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.29226867  7.97517886]
# Class Probabilities:  [2.71580591e-12 1.17677603e-02 2.65046395e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 9.46997908 -1.99299457]
# Class Probabilities:  [2.39959013e-13 3.36845606e-17 1.38599126e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.05416915 -2.47425901]
# Class Probabilities:  [3.74946814e-03 4.68398860e-07 5.06444924e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.21553241 12.53863186]
# Class Probabilities:  [8.06489516e-19 1.08467994e-03 4.74822490e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.85953786 -0.76518719]
# Class Probabilities:  [2.06773920e-11 3.60108200e-15 2.78656764e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.11560394 -2.51521659]
# Class Probabilities:  [2.59078377e-06 4.17946059e-09 2.79471378e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.88633577 -7.73994173]
# Class Probabilities:  [1.32138478e-02 2.03335120e-15 2.33177955e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.79933965  5.31322455]
# Class Probabilities:  [2.53450144e-09 2.35586965e-03 1.13693440e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.34271378 16.23529621]
# Class Probabilities:  [1.01454424e-28 2.78267113e-04 9.88574290e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.55913997 10.48707791]
# Class Probabilities:  [2.63166643e-15 4.43196647e-03 2.29496422e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.86122888  7.15903434]
# Class Probabilities:  [3.15434239e-12 5.64340133e-03 1.04219330e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.38794864  4.18558645]
# Class Probabilities:  [5.87505781e-09 1.73911088e-04 2.67347090e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.52727338 -7.21208436]
# Class Probabilities:  [1.37168706e-03 4.09520464e-21 7.19072076e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.98956144 -7.5666012 ]
# Class Probabilities:  [1.16718317e-02 3.77404758e-14 1.71546430e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.75405923 -5.30192282]
# Class Probabilities:  [6.95118009e-04 1.25640420e-17 3.55310352e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.94621632 -6.88516599]
# Class Probabilities:  [1.04371709e-02 2.04402037e-12 2.55802057e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31994442 -2.63044722]
# Class Probabilities:  [1.69857004e-03 4.89633087e-10 4.53858970e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-9.36297948 -8.56822792]
# Class Probabilities:  [2.89374922e-03 2.92800366e-22 2.03700860e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.81585174 -3.0905699 ]
# Class Probabilities:  [6.88546712e-03 6.52626989e-09 6.39617064e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.48384894 -2.13782697]
# Class Probabilities:  [2.43490266e-17 3.87480828e-22 2.42544600e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [7.38337554 4.66707989]
# Class Probabilities:  [5.90912052e-09 3.86405411e-10 7.24794243e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.19811716 -3.20869437]
# Class Probabilities:  [8.33437117e-03 1.52642313e-08 1.71444219e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.73664819 -5.64026754]
# Class Probabilities:  [1.73201508e-02 5.85707801e-12 2.18927069e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.16135146 8.11909452]
# Class Probabilities:  [1.39449795e-10 3.09076196e-06 1.16946817e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.93192373 -7.90304636]
# Class Probabilities:  [9.30691986e-03 1.91571573e-14 1.24385359e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.44663034 -1.10812617]
# Class Probabilities:  [5.29369481e-11 1.53334790e-14 3.20144569e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.41266737  -6.02755366]
# Class Probabilities:  [1.04013107e-04 7.28480745e-22 1.99048916e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-10.55452885  -6.98597699]
# Class Probabilities:  [2.43229231e-04 3.53443381e-23 5.08979751e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.16708742 -4.41114641]
# Class Probabilities:  [1.31152579e-03 1.73945702e-08 4.93438385e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.83499316 3.0513492 ]
# Class Probabilities:  [4.11740825e-08 1.05374227e-09 2.48195939e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.3218284   8.03062152]
# Class Probabilities:  [2.08715396e-12 1.19554118e-02 2.34516148e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.67262506 -3.63638033]
# Class Probabilities:  [9.59811438e-03 1.47628775e-08 3.15312012e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.23839346 15.50904654]
# Class Probabilities:  [6.66221640e-27 5.80140265e-04 7.70463760e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.85415463 -9.49083878]
# Class Probabilities:  [3.74127375e-06 1.39220876e-13 5.58979526e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.57934474 14.05416562]
# Class Probabilities:  [1.45103093e-25 4.14231332e-03 5.08444320e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.08121918 9.02118593]
# Class Probabilities:  [4.60310559e-13 7.31367381e-03 2.20074183e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.54545494 13.38470402]
# Class Probabilities:  [1.52996141e-28 6.66099852e-04 2.45389292e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.25685021 12.98458764]
# Class Probabilities:  [8.23191268e-22 5.87566748e-03 2.26792425e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.49117921 -2.09111202]
# Class Probabilities:  [8.81985134e-12 3.09762027e-15 2.31677847e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.6377611  2.59220877]
# Class Probabilities:  [4.14289177e-11 2.76739022e-15 1.09511929e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.99632131 -0.81831291]
# Class Probabilities:  [3.57531045e-10 1.63139390e-13 4.07559808e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.8066989  12.60496257]
# Class Probabilities:  [1.77028792e-18 4.04530476e-04 6.41031303e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.14054117 13.99755821]
# Class Probabilities:  [8.29453946e-25 4.00478064e-03 1.04918225e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.0622924  -4.14345298]
# Class Probabilities:  [1.18451137e-02 3.27311698e-09 1.26744563e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.73588097 -8.59503648]
# Class Probabilities:  [7.97952510e-03 3.68934487e-16 9.99969647e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.87691909 -8.51465367]
# Class Probabilities:  [5.59643710e-03 4.72737088e-15 5.97595158e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.30461631 -2.42881748]
# Class Probabilities:  [9.38363526e-12 4.27091878e-15 2.18519511e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.92551153  9.38904848]
# Class Probabilities:  [1.88205976e-16 8.79591699e-03 2.55603964e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-8.06681967 -9.76445434]
# Class Probabilities:  [4.58042496e-03 3.98146942e-21 9.32525457e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.24410989 -8.18831047]
# Class Probabilities:  [6.57602032e-03 1.25859907e-19 6.13090335e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.37602904 -5.99069434]
# Class Probabilities:  [1.70089603e-02 5.28923274e-13 4.59476165e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.22386765 -4.85135398]
# Class Probabilities:  [1.23773676e-06 3.90395369e-10 4.52107836e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.55406083 -2.89224039]
# Class Probabilities:  [2.63146431e-04 1.25919289e-07 5.91537590e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.69049165 13.4044702 ]
# Class Probabilities:  [2.95306578e-20 3.34545822e-04 8.41277317e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.53571156 10.66187251]
# Class Probabilities:  [5.60674395e-20 5.06738546e-03 8.10366449e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.96782552 -4.31305255]
# Class Probabilities:  [4.04246785e-07 2.56097109e-10 9.23284361e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.00081432  8.87275799]
# Class Probabilities:  [1.67515353e-15 7.88095526e-03 5.69502655e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.35696677 -3.77423836]
# Class Probabilities:  [5.68497572e-03 5.42958056e-11 2.53165539e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.48811048 -3.16156655]
# Class Probabilities:  [4.56384379e-11 4.08006820e-14 2.02979435e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.06573364 -13.36721214]
# Class Probabilities:  [7.53962488e-06 1.26531052e-22 7.00864282e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.1851141 2.6171304]
# Class Probabilities:  [8.14105432e-07 1.67541191e-07 2.98411577e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.27828524 1.31354615]
# Class Probabilities:  [1.10560112e-09 5.83850826e-13 3.39686697e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.79242965 1.64031539]
# Class Probabilities:  [9.26493895e-06 2.10737226e-06 2.98024083e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.138666   6.8602675]
# Class Probabilities:  [1.89448446e-10 8.12960587e-03 1.59428461e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.78244942 -9.12198008]
# Class Probabilities:  [2.29088889e-15 6.96110492e-17 3.52906701e-06]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.60435329 -5.38072375]
# Class Probabilities:  [1.82459307e-07 6.81871369e-11 3.28809550e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.85525938 -6.34543458]
# Class Probabilities:  [1.27879478e-02 8.38326992e-12 5.37571636e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.08621387  1.9348786 ]
# Class Probabilities:  [6.86376448e-17 1.31615909e-24 5.32648843e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.97701781 -8.26247269]
# Class Probabilities:  [3.61946379e-03 6.90964432e-14 4.26738881e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.3366769  1.22185752]
# Class Probabilities:  [1.29748321e-04 9.39161410e-05 2.76506246e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-9.28532526 -9.4355402 ]
# Class Probabilities:  [3.06955828e-03 4.14727404e-23 7.04757945e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.66429005 11.01189494]
# Class Probabilities:  [3.26437739e-16 3.60441554e-03 8.69323069e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.08966182 -1.69228564]
# Class Probabilities:  [2.45837105e-03 2.38064850e-07 3.38446733e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.33789356 -2.66619436]
# Class Probabilities:  [5.23541706e-09 6.31071565e-12 3.32398175e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.56901228  5.51033591]
# Class Probabilities:  [7.94607635e-09 4.31603213e-03 4.89059357e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.99286099 -4.68078563]
# Class Probabilities:  [2.84041621e-06 8.01002876e-10 4.67328161e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.80021733 11.42437424]
# Class Probabilities:  [9.51190489e-21 8.27063102e-03 5.18953611e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.16929961 -4.74585978]
# Class Probabilities:  [1.26842187e-04 5.78918372e-09 1.34516946e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.15245262 14.77479741]
# Class Probabilities:  [1.99538602e-26 2.19621691e-03 1.82856990e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.57247905  -6.73922446]
# Class Probabilities:  [2.60970513e-05 1.96025520e-25 3.08351966e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.60476346  4.55773513]
# Class Probabilities:  [9.05061892e-12 2.08984153e-06 2.51846197e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 7.91493717 -4.93203896]
# Class Probabilities:  [1.37003214e-13 3.13128814e-16 4.64153312e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.40280867 -4.97280708]
# Class Probabilities:  [1.25337122e-02 4.37925792e-12 1.04766222e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [2.04297042 2.03014309]
# Class Probabilities:  [2.90520922e-05 5.95100563e-05 9.35060708e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.21122011 -10.70086807]
# Class Probabilities:  [1.16055019e-03 2.72947307e-19 1.24362882e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.53064612 -8.83892725]
# Class Probabilities:  [6.04943349e-03 3.55431101e-16 1.05893797e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.30022088 11.20197432]
# Class Probabilities:  [1.75823191e-15 2.58282352e-04 2.02894788e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.52678262 11.00539841]
# Class Probabilities:  [3.54009949e-17 9.64922342e-03 2.79120680e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [6.2375991  2.80421505]
# Class Probabilities:  [1.36281023e-07 7.24159577e-09 2.95257846e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.1883182  -1.89030168]
# Class Probabilities:  [4.09664193e-05 5.03398170e-12 9.19628066e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.60122702 15.01466265]
# Class Probabilities:  [3.54712905e-28 2.21259958e-03 3.51254836e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.34641109 -4.86072033]
# Class Probabilities:  [3.91750203e-03 4.94832979e-09 8.83709780e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.63822042 -5.45296469]
# Class Probabilities:  [6.03133038e-12 1.54169681e-14 4.10065554e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [6.54807184 1.19913258]
# Class Probabilities:  [8.61501148e-08 5.25993309e-10 5.31205103e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [11.7595198   0.33353443]
# Class Probabilities:  [1.49437426e-15 1.69358739e-21 3.11246815e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.04384705  3.3153199 ]
# Class Probabilities:  [1.63552391e-11 5.69709296e-16 5.78023895e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.72322077 2.89573292]
# Class Probabilities:  [3.51937819e-06 8.15314483e-06 1.63550418e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.23412033 10.5086633 ]
# Class Probabilities:  [3.82776141e-22 4.26857523e-04 5.07665327e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [2.75812898 9.80988701]
# Class Probabilities:  [2.10400426e-13 8.77542453e-04 2.21523801e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [5.71709878 0.05250004]
# Class Probabilities:  [3.88528318e-07 2.23256642e-09 6.23703807e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.4383003  14.46253234]
# Class Probabilities:  [1.94242580e-33 8.08690626e-05 2.36867245e-16]
# Predicted class is : 2
# ******************************************************************************
# For test point: [10.31980548  5.65793048]
# Class Probabilities:  [6.53273159e-12 4.73874931e-16 7.50448404e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.37524372  -7.74958537]
# Class Probabilities:  [6.15613654e-04 1.39963553e-23 3.55299114e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.60020077 -5.42453553]
# Class Probabilities:  [1.69751359e-02 1.28312542e-11 3.41456853e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.20850522 -0.73094364]
# Class Probabilities:  [3.77193611e-05 3.74177765e-07 3.07100727e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.67511969 -0.45766944]
# Class Probabilities:  [5.99089215e-11 1.26600715e-14 3.18618462e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.84241029 -2.07200837]
# Class Probabilities:  [3.83779270e-03 1.82737691e-07 4.60607067e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.02815393 0.12504483]
# Class Probabilities:  [1.71035123e-06 1.83493623e-08 5.75557370e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.63527967 10.82193815]
# Class Probabilities:  [7.11998138e-16 3.86455197e-03 1.25293431e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.69546404 1.63793279]
# Class Probabilities:  [2.72878675e-06 2.48567539e-07 4.03485036e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.20495861 -8.54182529]
# Class Probabilities:  [3.29787152e-03 2.11363832e-14 1.93917585e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.85664823  8.27107861]
# Class Probabilities:  [1.78031938e-19 7.44871774e-06 1.07085956e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.43266395 -7.3131535 ]
# Class Probabilities:  [1.46025890e-02 2.13704360e-14 9.88712004e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.43743782 10.57358038]
# Class Probabilities:  [2.47270924e-14 2.22922199e-04 7.92812619e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.51691079 1.90895905]
# Class Probabilities:  [3.12738061e-06 5.16556325e-07 3.49280648e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.95393725 -2.06290005]
# Class Probabilities:  [3.88441291e-05 8.16947165e-08 2.03950987e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.17022706 -4.71914956]
# Class Probabilities:  [8.04241399e-03 3.29674523e-09 3.24852448e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.87943361 0.56763302]
# Class Probabilities:  [3.09445281e-08 7.83639651e-11 5.67104128e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.90155375 -2.49446135]
# Class Probabilities:  [8.28533794e-13 2.52940699e-16 1.57149903e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.75309704 10.13350214]
# Class Probabilities:  [2.82204044e-15 9.38313402e-03 2.06153664e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.83046209 -9.95463151]
# Class Probabilities:  [3.68858143e-03 2.76801527e-19 1.20296713e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.48084666 2.21690041]
# Class Probabilities:  [1.17515242e-08 4.16253904e-11 3.30256225e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.51484158 16.05856446]
# Class Probabilities:  [1.47744728e-36 1.26592170e-04 1.38472170e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.29796106 -1.51960377]
# Class Probabilities:  [2.55799100e-03 8.59738260e-07 1.19502289e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.04675075 14.39325425]
# Class Probabilities:  [2.80627347e-24 1.57901189e-03 1.44686549e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.33223697 -7.63241344]
# Class Probabilities:  [3.74324987e-03 1.08369963e-12 2.87594173e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.38944943 -9.23325113]
# Class Probabilities:  [1.74350247e-03 2.33165450e-15 4.97074369e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.74176393 -5.02512921]
# Class Probabilities:  [1.54083011e-02 2.13030263e-11 3.64044545e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.41004634 -5.5997003 ]
# Class Probabilities:  [4.72479959e-03 1.67497250e-15 7.84334771e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.09797276 -7.51282903]
# Class Probabilities:  [6.66456797e-03 1.26877934e-18 2.06837440e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.65055    14.73266536]
# Class Probabilities:  [2.10233285e-24 6.65526850e-04 1.04925987e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.15219027 3.63873026]
# Class Probabilities:  [2.77343132e-06 6.36133129e-04 1.75334228e-04]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.25543293  9.24132191]
# Class Probabilities:  [1.98383380e-15 1.25902253e-02 8.98402563e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.3701864  10.61688349]
# Class Probabilities:  [1.19045221e-19 5.98517265e-03 1.16796953e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.26329666  -7.92344489]
# Class Probabilities:  [1.70947561e-04 6.35565068e-26 2.08120755e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [1.37598504 5.76529642]
# Class Probabilities:  [2.37662743e-08 2.14944745e-03 2.98257146e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.88140712 -3.02402962]
# Class Probabilities:  [6.40177352e-03 6.49486002e-09 5.87202344e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.66886091 -1.94857083]
# Class Probabilities:  [2.50112082e-03 6.09575763e-08 1.21408936e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.21817753 10.22511294]
# Class Probabilities:  [6.50255138e-16 1.24195645e-02 9.52157822e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.01734447 -3.01633766]
# Class Probabilities:  [1.80200743e-05 1.55727700e-08 1.41456158e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.45242039 2.18725534]
# Class Probabilities:  [1.94002530e-05 4.03147708e-05 1.16243873e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.81338366 -3.04810313]
# Class Probabilities:  [2.64600874e-05 2.04907786e-08 1.25131410e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.35226244  7.94145336]
# Class Probabilities:  [4.08259310e-13 9.72111445e-03 6.86844610e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.32479122 -9.12757714]
# Class Probabilities:  [1.35614545e-04 1.08953435e-13 1.55592731e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.99032273 -0.46466519]
# Class Probabilities:  [9.09212829e-15 6.89958449e-20 6.28472332e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.52557256 -5.00051738]
# Class Probabilities:  [2.51159245e-03 3.92118016e-15 9.65818725e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31739532 -7.08917772]
# Class Probabilities:  [1.54196795e-02 5.00113412e-14 1.61626324e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.87484239  6.36256125]
# Class Probabilities:  [7.72653791e-12 1.46454170e-03 6.08403138e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.70055404 17.81508726]
# Class Probabilities:  [1.34099540e-38 1.38097821e-04 1.16559381e-18]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.83913631 -3.92362328]
# Class Probabilities:  [1.14205144e-02 1.32990267e-09 3.98931884e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31785661 -8.22012729]
# Class Probabilities:  [8.87303820e-03 3.14756247e-15 3.87796953e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.41220473 -0.78866093]
# Class Probabilities:  [4.36734964e-06 2.74063548e-08 4.85836641e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 5.86521872 -3.83801546]
# Class Probabilities:  [3.29106294e-09 4.10160545e-12 1.72275145e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.27975169 -5.40685681]
# Class Probabilities:  [6.99379748e-03 7.16663680e-10 1.57890329e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.44252378  5.04836557]
# Class Probabilities:  [5.80296384e-12 1.81675156e-16 1.21972249e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.10454519 -8.59923558]
# Class Probabilities:  [5.95092595e-03 2.12255175e-15 3.44317374e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.79291315 9.94727029]
# Class Probabilities:  [6.73888526e-15 9.23207464e-03 3.07018315e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.54304649 -2.92516109]
# Class Probabilities:  [1.80482683e-09 2.05098768e-12 2.85022722e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.39028133 12.45758209]
# Class Probabilities:  [1.94378584e-20 6.86481407e-03 9.43473349e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [9.43284293 1.63188371]
# Class Probabilities:  [4.32924495e-11 3.32271868e-15 1.75666361e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.09569772 1.68119391]
# Class Probabilities:  [6.32639932e-05 1.04571548e-04 4.94483926e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.85994525 -1.67404675]
# Class Probabilities:  [1.68790900e-10 8.90475163e-14 3.49734462e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.72753408  1.0240291 ]
# Class Probabilities:  [2.67887452e-13 1.69757363e-18 7.80539805e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.36857973 2.77908536]
# Class Probabilities:  [9.80483011e-06 7.97357010e-05 8.12707027e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.46358952 -4.88042874]
# Class Probabilities:  [1.50199827e-14 3.23030379e-17 3.79292016e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-8.6591206 -3.386283 ]
# Class Probabilities:  [4.72956560e-05 9.52451319e-16 1.48233033e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.4916236  0.68401163]
# Class Probabilities:  [3.73622212e-10 1.14020332e-13 3.45332956e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.09417452 -10.83373126]
# Class Probabilities:  [1.16854376e-03 1.33621674e-26 7.57845249e-17]
# Predicted class is : 1
# ...
# For test point: [10.36682284 -2.94025912]
# Class Probabilities:  [5.66046683e-16 7.21097350e-20 4.52003135e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.17686513 -0.67617114]
# Class Probabilities:  [7.59216302e-12 8.79532283e-16 2.36766019e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.56032018 10.89248968]
# Class Probabilities:  [2.30863123e-15 1.06205267e-03 2.33158323e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [0.8138255 6.3426885]
# Class Probabilities:  [3.02666303e-09 4.43510895e-03 8.83213571e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.58026808  9.29140022]
# Class Probabilities:  [7.17637911e-16 1.08757556e-02 5.13392541e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.85860141 -1.00596681]
# Class Probabilities:  [1.44485166e-11 2.63239146e-15 2.66877916e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.81652326 -2.73427081]
# Class Probabilities:  [3.33901330e-05 3.45349212e-08 1.45745792e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.91081684 -2.76984203]
# Class Probabilities:  [3.71535061e-03 3.00696835e-07 5.38800347e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.06815545  9.53292586]
# Class Probabilities:  [1.40742743e-19 5.74702003e-04 4.77086163e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [7.34079799 3.06978894]
# Class Probabilities:  [1.48914478e-08 1.51934665e-10 2.26077146e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.64032058 12.0068455 ]
# Class Probabilities:  [6.50538683e-22 7.83804919e-03 1.78927397e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.02141864 -0.12519999]
# Class Probabilities:  [1.47626638e-14 8.67245282e-20 6.31474435e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.83660161 7.63741536]
# Class Probabilities:  [3.10701257e-10 6.27669013e-04 8.38597289e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.55253392 -2.86889414]
# Class Probabilities:  [1.00709498e-03 2.50464817e-07 2.52437969e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.97166844 -3.22481456]
# Class Probabilities:  [1.73176033e-06 1.76718572e-09 1.88440279e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.98490968 -4.84749576]
# Class Probabilities:  [1.21777180e-02 9.10913060e-10 8.69879592e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.10588756 1.58507517]
# Class Probabilities:  [1.15411709e-10 1.61135044e-14 2.14732518e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.99945013 -3.95313184]
# Class Probabilities:  [3.91564910e-08 4.12299962e-11 1.51410560e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.71883232 15.1537229 ]
# Class Probabilities:  [2.21738513e-25 4.47917214e-04 3.44261356e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.33163346  9.72288532]
# Class Probabilities:  [1.88565101e-15 1.45484808e-02 1.27911708e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.04296746  1.25113376]
# Class Probabilities:  [1.08815624e-13 3.43146904e-19 5.70643366e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.22009129  9.65386874]
# Class Probabilities:  [3.24349819e-15 1.43269334e-02 1.67076049e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.70876068  2.17594789]
# Class Probabilities:  [1.21986894e-05 1.82075268e-04 1.53201435e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.51045177 7.56673947]
# Class Probabilities:  [5.92316772e-10 1.68156844e-05 2.16243137e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.29825485 13.66342044]
# Class Probabilities:  [1.36140279e-25 4.62363394e-03 5.15495791e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.72864588 -6.0121161 ]
# Class Probabilities:  [3.42108848e-04 2.57849099e-20 1.40733379e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.48899942 17.98748437]
# Class Probabilities:  [7.50745230e-37 1.40802681e-04 3.93903930e-18]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.77337683  7.24172304]
# Class Probabilities:  [1.82846794e-11 9.37785087e-03 4.27117817e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.05007773 15.12157932]
# Class Probabilities:  [7.26911041e-31 1.26493268e-03 2.96690678e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.79351842 -4.31693215]
# Class Probabilities:  [1.33742176e-02 6.75972042e-10 3.36839048e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.23987052 0.84895898]
# Class Probabilities:  [1.42366521e-08 2.72509386e-11 5.11210453e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.30596448 -3.23156572]
# Class Probabilities:  [3.6119655e-04 3.0277672e-13 4.6177555e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.28227684 -5.29628215]
# Class Probabilities:  [1.48842160e-02 3.07362467e-12 1.02867658e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.84284999 -4.65776943]
# Class Probabilities:  [3.81581129e-13 7.05247248e-16 6.09101458e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.36231452 14.65339584]
# Class Probabilities:  [4.71392571e-30 1.35765437e-03 6.67706795e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.11518005 -5.99608685]
# Class Probabilities:  [1.74825760e-02 1.04641843e-12 7.63346322e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.61237327 4.48009751]
# Class Probabilities:  [6.02795090e-10 1.64830646e-12 5.77005869e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.95457177 -2.6426557 ]
# Class Probabilities:  [6.53670626e-04 3.01023507e-07 4.02418845e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.91149048 -9.43001297]
# Class Probabilities:  [4.24091936e-03 2.40800382e-17 1.99133368e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.90520993  5.66899844]
# Class Probabilities:  [3.90070290e-14 1.99334816e-06 3.91989771e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.82381941  9.48699204]
# Class Probabilities:  [1.24023265e-20 1.23586801e-04 1.14999643e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.51481518 -2.69629369]
# Class Probabilities:  [8.36884281e-06 1.08783002e-08 2.07378156e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.81850398 -1.42510573]
# Class Probabilities:  [1.27780321e-06 4.01669651e-09 4.78753977e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.32369809 -7.1393455 ]
# Class Probabilities:  [5.70650363e-03 3.55394286e-12 5.35917776e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.46861438 -1.4433357 ]
# Class Probabilities:  [2.41400274e-04 2.40818637e-09 4.40989872e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.98740359 -5.57716425]
# Class Probabilities:  [5.01197389e-03 6.79102208e-10 2.04411095e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.65009927  4.93480248]
# Class Probabilities:  [1.74050436e-13 1.32351188e-19 4.77389861e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.29799896 -4.9997967 ]
# Class Probabilities:  [1.32065979e-02 5.49526378e-12 1.26484601e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.39210413 -8.94948394]
# Class Probabilities:  [5.65184071e-03 9.13826502e-21 1.46621181e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.03147831 -1.78716335]
# Class Probabilities:  [1.56839018e-03 1.68620582e-06 2.18048985e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.24658383 -0.90643208]
# Class Probabilities:  [3.34587031e-09 3.08894208e-12 5.04991230e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.56004924 -1.02757626]
# Class Probabilities:  [1.98925268e-05 1.27560685e-07 3.48767072e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.36264317 -0.22355351]
# Class Probabilities:  [4.76399471e-09 4.75501306e-12 5.27385936e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.87468243  1.68851414]
# Class Probabilities:  [3.05689129e-06 6.69081616e-06 5.86536672e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.71271544 -9.47990792]
# Class Probabilities:  [2.33189857e-05 8.15046397e-14 2.01538913e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-6.79673036 -6.33979581]
# Class Probabilities:  [1.11093472e-02 2.94809070e-15 1.61473619e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.06008745 9.97311029]
# Class Probabilities:  [1.43331679e-15 1.33326028e-02 1.28649862e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.82746067 -3.56345126]
# Class Probabilities:  [6.54187104e-03 3.12321835e-10 8.01636894e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.90632459 -9.21895769]
# Class Probabilities:  [6.21387818e-03 3.43114934e-20 3.23526984e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.36874346 0.62545597]
# Class Probabilities:  [8.95084769e-09 1.27728997e-11 5.11348416e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.22552188 -0.20662172]
# Class Probabilities:  [3.55276896e-10 1.32005883e-13 3.97357430e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.20850538 -2.82403166]
# Class Probabilities:  [4.45033124e-04 1.87472417e-07 4.62617060e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.21579751 2.94840046]
# Class Probabilities:  [4.92574902e-06 2.33290999e-05 1.23768493e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.20729307 -5.44771275]
# Class Probabilities:  [6.48176890e-03 7.12282664e-10 1.68874384e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.40036386 -5.32174925]
# Class Probabilities:  [1.44906232e-02 2.11649095e-12 7.96126352e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.15531485 -4.12155615]
# Class Probabilities:  [1.01785114e-03 2.94580883e-08 8.44374321e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.22382129 5.71360307]
# Class Probabilities:  [7.86496547e-11 1.59105047e-13 1.39962775e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.63952042 -4.65786291]
# Class Probabilities:  [2.03244303e-03 1.01082227e-08 2.43494543e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.15705042 1.29990602]
# Class Probabilities:  [7.95674928e-11 9.43749531e-15 2.23672038e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.95944226  1.34437573]
# Class Probabilities:  [1.67574468e-13 6.14107631e-19 6.03757634e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [12.70138697  4.8417071 ]
# Class Probabilities:  [5.15742837e-15 1.33332350e-22 1.68605356e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.13412403 8.8823782 ]
# Class Probabilities:  [4.67545243e-12 5.33499368e-11 3.31316253e-06]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.02416693 11.64233379]
# Class Probabilities:  [1.43515637e-21 6.75181461e-03 2.25681699e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.06908312 1.27293507]
# Class Probabilities:  [1.03682344e-04 6.78552613e-05 5.54511738e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.66236602 -2.51130178]
# Class Probabilities:  [3.55271542e-14 5.84999533e-18 9.69454762e-04]
# Predicted class is : 3
# ******************************************************************************

# %%
# TODO [8]: Compute the accuracy of the generated Bayesian classifier 
# WITHOUT USING ANY FOR LOOPs.
test_data_true = np.array(test_data_true, dtype=float).astype(int)
test_data_true=test_data_true.reshape(1,-1)[0]
accuracy=np.sum(predicted_classes == test_data_true)/K
print('Accuracy = ' + str(round(accuracy,4) * 100) + '%')
# Out:
# Accuracy = 95.56%

# %%
# TODO [9]: Generate a 3D-plot for the generated distributions. x-axis and y-axis represent the features of the data, 
#           where z-axis represent the Gaussian probability N at this point.
x = np.linspace(-10, 10, 300)
y = np.linspace(-10, 15, 300)
X, Y = np.meshgrid(x, y)
Z =np.zeros(X.shape)
for i in range(Z.shape[0]):
    for j in range(Z.shape[1]):
        # TODO [9]: Fill in the matrix Z which will represent the probability distribution of every point.
        # Z[i,j] represents the joint probability N(x,y) for x = i and y = j. 
        # We want to draw the gaussian probability N(x,y) for all points. 
        point = np.array([X[i, j], Y[i, j]])
        Z1 = multivariate_normal_gaussian(point,estimate_means[0],estimate_covariances[0])*pClasses[0]
        Z2= multivariate_normal_gaussian( point,estimate_means[1],estimate_covariances[1])*pClasses[1]
        Z3= multivariate_normal_gaussian( point,estimate_means[2],estimate_covariances[2])*pClasses[2]
        Z[i,j]=max(Z1,Z2,Z3)


        # Make a 3D plot, do not change code
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()

# %%
# How can you judge your plot is correct?
'''
    Your Answer:
    1-there are 3 peaks in the plot because we have 3 classes
    2-the plot is 3 dimesnional because we have 2 features not only one
    3-if we looked at the top view of the plot, we'll find that the centers of the distribustions are their means which we calculated in estimated means
    4-we'll also find that the curves with larger covariances are wider
'''
# Out:
# '\n    Your Answer:\n'
